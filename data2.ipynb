# %%
import pandas as pd
import numpy as np

# %%
cols = pd.read_excel("/Users/aryanrajsaxena/Desktop/BarryC/data_analysis/data-files/Column Schema.xlsx", usecols=['Column', "Status"])

# %%
cols
# Out:
#                            Column    Status
# 0                 Dry_Milk_Solids    Active
# 1                         MilkFat    Active
# 2    Alkalizing_Agent_K2CO3_DFFCS    Active
# 3                        Sugars_g    Active
# 4            Min_Dry_Cocoa_Solids    Active
# ..                            ...       ...
# 278          Dosage_Test_Grams_To  Inactive
# 279             Dosage_Test_Grams  Inactive
# 280                 Certification     Other
# 281       Legislation_Description     Other
# 282          Material_Group_Short     Other
#
# [283 rows x 2 columns]

# %%
active_cols=cols[cols['Status'] == "Active"]['Column'].to_list()

# %%
"Legislation" in active_cols
# Out:
# False

# %%
active_cols.append("Material_Code")
active_cols.append("Description")
active_cols.append("Material_Group")
active_cols.append("Material_Description")
active_cols.append("Commercial_Name")
active_cols.append("Smallest_Unit_Weight_In_Kg")
active_cols.append("Units_Per_Pallet")
active_cols.append("Packaging_Info")
active_cols.append("Legislation")

# %%
df=pd.read_excel('/Users/aryanrajsaxena/Desktop/BarryC/data_analysis/data-files/Master Data - Part 1.xlsx', usecols=active_cols)

# %%
null_summary = (
    pd.DataFrame({
        'null_count': df.isna().sum(),
        'percent_null': (df.isna().mean() * 100).round(2)
    })
    .sort_values('percent_null', ascending=False)
)

# %% [markdown]
# ## removing columns with more than 95% null values - total 17 columns

# %%
drop_cols =null_summary.head(17).index.to_list()

# %%
df.drop(columns=drop_cols, inplace=True)

# %% [markdown]
# include Commercial_Name , Smallest_Unit_Weight_In_Kg , Units_Per_Pallet , Brand , components_Specifications , Colour_TF , Colour_Type_Tag , Flavor_Type_Tag , Kosher_Certificate, Shelflife , Packaging_Info

# %%
df
# Out:
#             Material_Code                      Material_Description  \
# 0      100-F17C237-01-793              BD 10/12 LC 25KG/BG 30BG/PAL
# 1      100-F17C238-01-793              BD 20/22 LC 25KG/BG 30BG/PAL
# 2      100-F17C238-01-793              BD 20/22 LC 25KG/BG 30BG/PAL
# 3              100001-34B                              BD 10/12 DDP
# 4              100001-34C             BD 10/12 DDP 25KG/BG 36BG/PAL
# ...                   ...                                       ...
# 15068  YYW-PN-G300297-E15     GH SFT WHITE PETITE POPS PAN 20LB/BOX
# 15069  YYX-OS-G300291-E11   GH SFT MK/DK FUDGE TRUFFLE OSM 300CT/LB
# 15070  YYX-PN-G203940-E67  96_GH SFT CARM PNT SPLT/MK PAN 1500CT/LB
# 15071  YYX-PN-G203940-E67  96_GH SFT CARM PNT SPLT/MK PAN 1500CT/LB
# 15072  YYX-PN-G203940-E67  96_GH SFT CARM PNT SPLT/MK PAN 1500CT/LB
#
#       Legislation  Min_Dry_Cocoa_Solids  Dry_Milk_Solids  MilkFat  \
# 0              EU                   NaN              NaN      NaN
# 1              EU                   NaN              NaN      NaN
# 2              US                   NaN              NaN      NaN
# 3              MY                   NaN              NaN      NaN
# 4              EU                   NaN              NaN      NaN
# ...           ...                   ...              ...      ...
# 15068         NaN                   NaN              NaN      NaN
# 15069          US                   NaN              NaN      NaN
# 15070          CA                   NaN              NaN      NaN
# 15071          MX                   NaN              NaN      NaN
# 15072          US                   NaN              NaN      NaN
#
#        Dry_Fat_Free_Cocoa_Solids Material_Group  \
# 0                            NaN   Cocoa Powder
# 1                            NaN   Cocoa Powder
# 2                            NaN   Cocoa Powder
# 3                            NaN   Cocoa Powder
# 4                            NaN   Cocoa Powder
# ...                          ...            ...
# 15068                        NaN      Compounds
# 15069                        NaN      Compounds
# 15070                        NaN      Compounds
# 15071                        NaN      Compounds
# 15072                        NaN      Compounds
#
#                                components_Specifications  Sugars_g  ...   pH  \
# 0                 {'fat-reduced cocoa powder': '100.0%'}       0.5  ...  5.8
# 1                             {'cocoa powder': '100.0%'}       0.4  ...  5.8
# 2                                                    NaN       0.4  ...  5.8
# 3                             {'cocoa powder': '100.0%'}       0.5  ...  8.0
# 4      {'acidity regulator(e 501i)': '7.0%', 'fat-red...       0.5  ...  8.0
# ...                                                  ...       ...  ...  ...
# 15068  {'toasted wheat crisp kosher': '20.0%', 'bc wh...       NaN  ...  NaN
# 15069  {'sea salt': '0.32%', 'organic non-fat dry mil...      48.6  ...  NaN
# 15070  {'sugar': '33.92%', 'emulsifier(soya lecithin)...      38.9  ...  NaN
# 15071  {'salt': '0.7%', 'natural flavouring': '0.09%'...      38.9  ...  NaN
# 15072  {'coconut oil': '21.6%', 'salt': '0.7%', 'whol...      38.9  ...  NaN
#
#        Normalised_Yield_Pa Normalised_Linear_Viscosity_mPaS  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
# ...                    ...                              ...
# 15068                  NaN                              NaN
# 15069                  NaN                              NaN
# 15070                  NaN                              NaN
# 15071                  NaN                              NaN
# 15072                  NaN                              NaN
#
#       Normalised_Casson_Mpa_S Brookfield_40C_S27_20_RPM Fineness_Micrometer  \
# 0                         NaN                       NaN                 NaN
# 1                         NaN                       NaN                 NaN
# 2                         NaN                       NaN                 NaN
# 3                         NaN                       NaN                 NaN
# 4                         NaN                       NaN                 NaN
# ...                       ...                       ...                 ...
# 15068                     NaN                       NaN                 NaN
# 15069                     NaN                       NaN                 NaN
# 15070                     NaN                       NaN                 NaN
# 15071                     NaN                       NaN                 NaN
# 15072                     NaN                       NaN                 NaN
#
#       Dimensions_Length Dimensions_Width Dimensions_Count_lb  \
# 0                   NaN              NaN                 NaN
# 1                   NaN              NaN                 NaN
# 2                   NaN              NaN                 NaN
# 3                   NaN              NaN                 NaN
# 4                   NaN              NaN                 NaN
# ...                 ...              ...                 ...
# 15068               NaN              NaN                 NaN
# 15069               NaN              NaN               300.0
# 15070               NaN              NaN              1500.0
# 15071               NaN              NaN              1500.0
# 15072               NaN              NaN              1500.0
#
#                                              Description
# 0      Material: Natural Powder cocoa and comes in Po...
# 1      Material: Natural Powder cocoa and comes in Po...
# 2      Material: Natural Powder cocoa and comes in Po...
# 3      Material: Alcalised Powder cocoa and comes in ...
# 4      Material: Alcalised Powder cocoa and comes in ...
# ...                                                  ...
# 15068  Material: White icecoating. It is described as...
# 15069  Material: Mix icecoating. It is described as S...
# 15070  Material: Mix icecoating. It is described as S...
# 15071  Material: Mix icecoating. It is described as S...
# 15072  Material: Mix icecoating. It is described as S...
#
# [15073 rows x 63 columns]

# %%
df['components_Specifications'].unique()[15]
# Out:
# "{'acidity regulator(e 330)': '0.3%', 'fat-reduced cocoa powder': '94.1%', 'acidity regulator(e 501i)': '5.6%'}"

# %%
df.columns
# Out:
# Index(['Material_Code', 'Material_Description', 'Legislation',
#        'Min_Dry_Cocoa_Solids', 'Dry_Milk_Solids', 'MilkFat',
#        'Dry_Fat_Free_Cocoa_Solids', 'Material_Group',
#        'components_Specifications', 'Sugars_g', 'Protein_g', 'Total_Fat_g',
#        'Contains_Milk_Proteins', 'Contains_Egg_Products',
#        'Contains_Soy_Proteins', 'Contains_Wheat', 'Contains_Rye',
#        'Contains_Fish', 'Contains_Crustacean_And_Shell_Fish',
#        'Contains_Hazelnuts_Almonds', 'Contains_Peanuts',
#        'Contains_Sulphite_E220_E227', 'Contains_Celery',
#        'Contains_Sesame_Products', 'Suitable_For_Vegetarians',
#        'Suitable_For_Vegans', 'Contains_Peanut_Oil', 'Contains_Mustard',
#        'Contains_Molluscs', 'Contains_Lupin', 'Contains_Buckwheat',
#        'Base_Type', 'Moulding_Type', 'Product_Type', 'Colour_TF',
#        'Kosher_Certificate', 'Country_Claim', 'Shelflife', 'Packaging_Info',
#        'Brand', 'Commercial_Name', 'Contains_Hydrogenated', 'Hydrogenated',
#        'Smallest_Unit_Weight_In_Kg', 'Units_Per_Pallet', 'Certification_Tag',
#        'Colour_Type_Tag', 'Flavor_Type_Tag', 'Shape', 'SKU_Material_Tag',
#        'Origin', 'Sku_Ingredient_Tag', 'Is_Organic', 'pH',
#        'Normalised_Yield_Pa', 'Normalised_Linear_Viscosity_mPaS',
#        'Normalised_Casson_Mpa_S', 'Brookfield_40C_S27_20_RPM',
#        'Fineness_Micrometer', 'Dimensions_Length', 'Dimensions_Width',
#        'Dimensions_Count_lb', 'Description'],
#       dtype='object')

# %% [markdown]
# for now remove commercial name and components specifications

# %%
df.drop(columns=['Material_Description', 'Description'], inplace=True)

# %%
df
# Out:
#             Material_Code Legislation  Min_Dry_Cocoa_Solids  Dry_Milk_Solids  \
# 0      100-F17C237-01-793          EU                   NaN              NaN
# 1      100-F17C238-01-793          EU                   NaN              NaN
# 2      100-F17C238-01-793          US                   NaN              NaN
# 3              100001-34B          MY                   NaN              NaN
# 4              100001-34C          EU                   NaN              NaN
# ...                   ...         ...                   ...              ...
# 15068  YYW-PN-G300297-E15         NaN                   NaN              NaN
# 15069  YYX-OS-G300291-E11          US                   NaN              NaN
# 15070  YYX-PN-G203940-E67          CA                   NaN              NaN
# 15071  YYX-PN-G203940-E67          MX                   NaN              NaN
# 15072  YYX-PN-G203940-E67          US                   NaN              NaN
#
#        MilkFat  Dry_Fat_Free_Cocoa_Solids Material_Group  \
# 0          NaN                        NaN   Cocoa Powder
# 1          NaN                        NaN   Cocoa Powder
# 2          NaN                        NaN   Cocoa Powder
# 3          NaN                        NaN   Cocoa Powder
# 4          NaN                        NaN   Cocoa Powder
# ...        ...                        ...            ...
# 15068      NaN                        NaN      Compounds
# 15069      NaN                        NaN      Compounds
# 15070      NaN                        NaN      Compounds
# 15071      NaN                        NaN      Compounds
# 15072      NaN                        NaN      Compounds
#
#                                components_Specifications  Sugars_g  Protein_g  \
# 0                 {'fat-reduced cocoa powder': '100.0%'}       0.5       22.7
# 1                             {'cocoa powder': '100.0%'}       0.4       19.9
# 2                                                    NaN       0.4       19.9
# 3                             {'cocoa powder': '100.0%'}       0.5       22.2
# 4      {'acidity regulator(e 501i)': '7.0%', 'fat-red...       0.5       22.2
# ...                                                  ...       ...        ...
# 15068  {'toasted wheat crisp kosher': '20.0%', 'bc wh...       NaN        NaN
# 15069  {'sea salt': '0.32%', 'organic non-fat dry mil...      48.6        5.7
# 15070  {'sugar': '33.92%', 'emulsifier(soya lecithin)...      38.9       10.8
# 15071  {'salt': '0.7%', 'natural flavouring': '0.09%'...      38.9       10.8
# 15072  {'coconut oil': '21.6%', 'salt': '0.7%', 'whol...      38.9       10.8
#
#        ...  Is_Organic   pH Normalised_Yield_Pa  \
# 0      ...          No  5.8                 NaN
# 1      ...          No  5.8                 NaN
# 2      ...          No  5.8                 NaN
# 3      ...          No  8.0                 NaN
# 4      ...          No  8.0                 NaN
# ...    ...         ...  ...                 ...
# 15068  ...          No  NaN                 NaN
# 15069  ...         Yes  NaN                 NaN
# 15070  ...          No  NaN                 NaN
# 15071  ...          No  NaN                 NaN
# 15072  ...          No  NaN                 NaN
#
#       Normalised_Linear_Viscosity_mPaS Normalised_Casson_Mpa_S  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
# ...                                ...                     ...
# 15068                              NaN                     NaN
# 15069                              NaN                     NaN
# 15070                              NaN                     NaN
# 15071                              NaN                     NaN
# 15072                              NaN                     NaN
#
#       Brookfield_40C_S27_20_RPM Fineness_Micrometer Dimensions_Length  \
# 0                           NaN                 NaN               NaN
# 1                           NaN                 NaN               NaN
# 2                           NaN                 NaN               NaN
# 3                           NaN                 NaN               NaN
# 4                           NaN                 NaN               NaN
# ...                         ...                 ...               ...
# 15068                       NaN                 NaN               NaN
# 15069                       NaN                 NaN               NaN
# 15070                       NaN                 NaN               NaN
# 15071                       NaN                 NaN               NaN
# 15072                       NaN                 NaN               NaN
#
#       Dimensions_Width Dimensions_Count_lb
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ...                ...                 ...
# 15068              NaN                 NaN
# 15069              NaN               300.0
# 15070              NaN              1500.0
# 15071              NaN              1500.0
# 15072              NaN              1500.0
#
# [15073 rows x 61 columns]

# %%
df[df['Material_Code']=='YYW-PN-G300297-E15'].loc[:, 'components_Specifications'].values[0]
# Out:
# "{'natural flavouring': '0.02%', 'malt extract(barley)': '0.4%', 'whole wheat flour': '14.6%', 'raising agent(e 500ii)': '0.38%', 'skimmed milk powder': '6.92%', 'salt': '0.26%', 'coconut oil': '19.51%', 'emulsifier(soya lecithin)': '0.22%', 'modified palm kernel oil': '4.88%', 'whole milk powder': '0.46%', 'natural vanilla extract': '0.04%', 'sugar': '49.67%', 'butter oil': '2.66%'}"

# %%
def match_by_material_code(df: pd.DataFrame, material_code, code_col='Material_Code'):
    """
    Return rows whose (Material_Group, Base_Type, Moulding_Type, Product_Type)
    exactly match the values of the given material_code in df.
    If multiple rows share the material_code, the first match is used.
    """
    cols = ['Material_Group', 'Base_Type', 'Moulding_Type', 'Product_Type']
    required = [code_col] + cols
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    ref_rows = df.loc[df[code_col] == material_code, cols]
    if ref_rows.empty:
        # No such material_code
        return df.iloc[0:0].copy()

    ref = ref_rows.iloc[0]  # use first occurrence
    mask = pd.Series(True, index=df.index)
    for c in cols:
        v = ref[c]
        mask &= (df[c].isna() if pd.isna(v) else df[c].eq(v))

    return df.loc[mask].copy()

# %%
matches = match_by_material_code(df,'YYW-PN-G300297-E15')

# %%
matches[['Material_Group', 'Base_Type', 'Moulding_Type', 'Product_Type']]
# Out:
#       Material_Group Base_Type   Moulding_Type Product_Type
# 15065      Compounds     White  Panned product   icecoating
# 15066      Compounds     White  Panned product   icecoating
# 15067      Compounds     White  Panned product   icecoating
# 15068      Compounds     White  Panned product   icecoating

# %%
matches
# Out:
#             Material_Code Legislation  Min_Dry_Cocoa_Solids  Dry_Milk_Solids  \
# 15065  YYW-PN-G300297-E15          CA                   NaN              NaN
# 15066  YYW-PN-G300297-E15          MX                   NaN              NaN
# 15067  YYW-PN-G300297-E15          US                   NaN              NaN
# 15068  YYW-PN-G300297-E15         NaN                   NaN              NaN
#
#        MilkFat  Dry_Fat_Free_Cocoa_Solids Material_Group  \
# 15065      NaN                        NaN      Compounds
# 15066      NaN                        NaN      Compounds
# 15067      NaN                        NaN      Compounds
# 15068      NaN                        NaN      Compounds
#
#                                components_Specifications  Sugars_g  Protein_g  \
# 15065  {'natural flavouring': '0.02%', 'malt extract(...      53.8        4.0
# 15066  {'natural flavouring': '0.02%', 'malt extract(...      53.8        4.0
# 15067  {'raising agent(e 500ii)': '0.38%', 'natural f...      53.8        4.0
# 15068  {'toasted wheat crisp kosher': '20.0%', 'bc wh...       NaN        NaN
#
#        ...  Is_Organic  pH Normalised_Yield_Pa  \
# 15065  ...          No NaN                 NaN
# 15066  ...          No NaN                 NaN
# 15067  ...          No NaN                 NaN
# 15068  ...          No NaN                 NaN
#
#       Normalised_Linear_Viscosity_mPaS Normalised_Casson_Mpa_S  \
# 15065                              NaN                     NaN
# 15066                              NaN                     NaN
# 15067                              NaN                     NaN
# 15068                              NaN                     NaN
#
#       Brookfield_40C_S27_20_RPM Fineness_Micrometer Dimensions_Length  \
# 15065                       NaN                 NaN               NaN
# 15066                       NaN                 NaN               NaN
# 15067                       NaN                 NaN               NaN
# 15068                       NaN                 NaN               NaN
#
#       Dimensions_Width Dimensions_Count_lb
# 15065              NaN                 NaN
# 15066              NaN                 NaN
# 15067              NaN                 NaN
# 15068              NaN                 NaN
#
# [4 rows x 61 columns]

# %%
import ast

# choose the correct column name
spec_col = 'components_Specifications'
if spec_col not in matches.columns:
    raise KeyError("components_Specifications/component_Specifications column not found in matches")

def _parse_dict_cell(x):
    if isinstance(x, dict):
        return x
    if pd.isna(x):
        return {}
    try:
        return ast.literal_eval(str(x))
    except Exception:
        return {}

def _flatten(d, parent=''):
    out = {}
    if not isinstance(d, dict):
        return out
    for k, v in d.items():
        key = f"{parent}.{k}" if parent else f"{k}"
        if isinstance(v, dict):
            out.update(_flatten(v, key))
        else:
            # normalize list/tuple/set to a string so it's usable as a single value
            if isinstance(v, (list, tuple, set)):
                try:
                    v = ";".join(map(str, v))
                except Exception:
                    v = str(v)
            out[key] = v
    return out

# Convert percentage-like strings to float (e.g., "12.5%" -> 12.5)
def _strip_percent_to_float(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    obj_cols = out.select_dtypes(include=['object']).columns
    for c in obj_cols:
        s = out[c]
        has_pct = s.astype(str).str.contains('%', na=False)
        if not has_pct.any():
            continue
        # strip %, commas, spaces; convert to numeric
        cleaned = s.astype(str).str.replace('%', '', regex=False).str.replace(',', '', regex=False).str.strip()
        out[c] = pd.to_numeric(cleaned, errors='coerce')
    return out

def get_spec_keys_from_material(df, material_code, spec_col='components_Specifications'):
    """Get component specification keys from a specific material code"""
    material_idx = df.index[df['Material_Code'] == material_code][0]
    material_specs = df.loc[material_idx, spec_col]
    spec_dict = _parse_dict_cell(material_specs)
    return list(_flatten(spec_dict).keys())

# %%
# Get the keys from the reference material code
material_code = 'YYW-PN-G300297-E15'
spec_keys = get_spec_keys_from_material(df, material_code)

# parse and flatten each row's dict, but only keep the keys from reference material
parsed = matches[spec_col].apply(_parse_dict_cell).apply(_flatten)

# build a DataFrame with only the reference material's keys, NaN where missing
spec_df = pd.DataFrame([{k: d.get(k, np.nan) for k in spec_keys} 
                       for d in parsed], index=matches.index)

# best-effort numeric coercion so numeric-looking strings become numbers
spec_df = spec_df.apply(pd.to_numeric, errors='ignore')

# join back and drop the original dict column
matches_expanded = matches.drop(columns=[spec_col]).join(spec_df)

# convert percentage values to floats
matches_expanded = _strip_percent_to_float(matches_expanded)
# Out:
# /var/folders/hn/vdrc8_bx3bqbs08ppwsr68x00000gp/T/ipykernel_77853/3390665476.py:13: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   spec_df = spec_df.apply(pd.to_numeric, errors='ignore')

# %%
matches_expanded
# Out:
#             Material_Code Legislation  Min_Dry_Cocoa_Solids  Dry_Milk_Solids  \
# 15065  YYW-PN-G300297-E15          CA                   NaN              NaN
# 15066  YYW-PN-G300297-E15          MX                   NaN              NaN
# 15067  YYW-PN-G300297-E15          US                   NaN              NaN
# 15068  YYW-PN-G300297-E15         NaN                   NaN              NaN
#
#        MilkFat  Dry_Fat_Free_Cocoa_Solids Material_Group  Sugars_g  Protein_g  \
# 15065      NaN                        NaN      Compounds      53.8        4.0
# 15066      NaN                        NaN      Compounds      53.8        4.0
# 15067      NaN                        NaN      Compounds      53.8        4.0
# 15068      NaN                        NaN      Compounds       NaN        NaN
#
#        Total_Fat_g  ... raising agent(e 500ii) skimmed milk powder  salt  \
# 15065         27.7  ...                   0.38                6.92  0.26
# 15066         27.7  ...                   0.38                6.92  0.26
# 15067         27.7  ...                   0.38                 NaN  0.26
# 15068          NaN  ...                    NaN                 NaN   NaN
#
#       coconut oil emulsifier(soya lecithin) modified palm kernel oil  \
# 15065       19.51                      0.22                     4.88
# 15066         NaN                      0.22                      NaN
# 15067       19.51                      0.22                      NaN
# 15068         NaN                       NaN                      NaN
#
#       whole milk powder natural vanilla extract  sugar butter oil
# 15065              0.46                    0.04  49.67       2.66
# 15066              0.46                    0.04  49.67        NaN
# 15067              0.46                    0.04  49.67        NaN
# 15068               NaN                     NaN    NaN        NaN
#
# [4 rows x 73 columns]

# %%
import numpy as np
import pandas as pd
from typing import Optional, Iterable, Union

def gower_similarity(
    df: pd.DataFrame,
    query_idx,
    weights: Optional[Union[dict, pd.Series]] = None,
    boost: str = 'count',            # 'count' or 'weight'
    normalize: bool = True,          # True -> final score kept in [0,1]
    exclude_cols: Optional[Iterable[str]] = None
) -> pd.DataFrame:
    """
    Weighted Gower-like similarity with anchor-centric missing value handling:
    
    Case 1: Anchor NaN, candidate has value -> Column counts as used (15/15)
    Case 2: Anchor has value, candidate NaN -> Column counts as not used (14/15)
    Case 3: Both NaN -> Column counts as used (15/15)
    Case 4: Both have values -> Standard distance calculation
    """
    # Defensive copy
    X = df.copy()

    # Drop excluded columns
    if exclude_cols:
        exclude = [c for c in exclude_cols if c in X.columns]
        X = X.drop(columns=exclude)

    cols = X.columns.tolist()
    n = len(X)
    if len(cols) == 0:
        raise ValueError("No columns left after excluding columns.")

    # split numeric / categorical
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = [c for c in cols if c not in num_cols]

    # build weight series (default 1.0)
    if weights is None:
        w = pd.Series(1.0, index=cols, dtype='float64')
    else:
        if isinstance(weights, pd.Series):
            w = pd.Series(1.0, index=cols, dtype='float64')
            for k, v in weights.items():
                if k in w.index:
                    w[k] = float(v)
        elif isinstance(weights, dict):
            w = pd.Series(1.0, index=cols, dtype='float64')
            for k, v in weights.items():
                if k in w.index:
                    w[k] = float(v)
        else:
            raise TypeError("weights must be None, dict, or pd.Series")

    # pick query row (by index label)
    q = X.loc[query_idx]

    # NUMERIC PART
    if num_cols:
        A = X[num_cols].to_numpy(dtype='float64')          # shape (n, m_num)
        qA = q[num_cols].to_numpy(dtype='float64')         # shape (m_num,)
        
        # Anchor-centric missing value handling
        anchor_nan = np.isnan(qA)                          # True where anchor is NaN
        data_nan = np.isnan(A)                             # True where data is NaN
        
        # Cases 1 & 3: Anchor NaN and (candidate has value OR candidate NaN) -> count as used
        # Case 2: Anchor has value, candidate NaN -> count as not used
        # Case 4: Both have values -> standard comparison
        used_num = (~anchor_nan & ~data_nan) | anchor_nan  # Case 4 OR (Case 1 & 3)
        
        # For distance calculation, only use where both have values (Case 4)
        valid_compare = ~anchor_nan & ~data_nan
        
        # ranges robust to all-NaN columns:
        col_max = np.nanmax(A, axis=0)
        col_min = np.nanmin(A, axis=0)
        ranges = col_max - col_min
        ranges = np.where(np.isnan(ranges) | (ranges == 0), 1.0, ranges)
        
        diff = np.abs(A - qA)                              # broadcast (n, m_num)
        comp_num = diff / ranges                           # scaled numeric difference
        comp_num[~valid_compare] = 0.0                     # zero distance for Case 1,2,3
        
        w_num = w[num_cols].to_numpy(dtype='float64')      
        num_sum = (comp_num * w_num).sum(axis=1)          
        num_used_w = (used_num * w_num).sum(axis=1)       # weight sum reflects anchor-centric logic
        num_used_cnt = used_num.sum(axis=1)               # count reflects anchor-centric logic
    else:
        num_sum = np.zeros(n, dtype='float64')
        num_used_w = np.zeros(n, dtype='float64')
        num_used_cnt = np.zeros(n, dtype='int64')

    # CATEGORICAL PART
    if cat_cols:
        B = X[cat_cols].astype(object)
        qB = q[cat_cols].astype(object)
        
        # Anchor-centric missing value handling for categorical
        anchor_miss = pd.isna(qB.values)                   # True where anchor is missing
        data_miss = B.isna().values                        # True where data is missing
        
        # Same logic as numeric part
        used_cat = (~anchor_miss & ~data_miss) | anchor_miss
        valid_compare = ~anchor_miss & ~data_miss
        
        # equality check only where both have values
        equal = (B.values == qB.values) & valid_compare
        comp_cat = (~equal).astype('float64')             # 1.0 if different, 0.0 if same or any NaN
        
        w_cat = w[cat_cols].to_numpy(dtype='float64')
        cat_sum = (comp_cat * w_cat).sum(axis=1)
        cat_used_w = (used_cat * w_cat).sum(axis=1)      # weight sum reflects anchor-centric logic
        cat_used_cnt = used_cat.sum(axis=1)              # count reflects anchor-centric logic
    else:
        cat_sum = np.zeros(n, dtype='float64')
        cat_used_w = np.zeros(n, dtype='float64')
        cat_used_cnt = np.zeros(n, dtype='int64')

    used_w = num_used_w + cat_used_w
    used_cnt = num_used_cnt + cat_used_cnt
    comp_sum = num_sum + cat_sum

    # distance calculation (now safer since we zero-out invalid comparisons)
    with np.errstate(invalid='ignore', divide='ignore'):
        dist = comp_sum / used_w
    dist = np.where(used_w == 0, np.nan, dist)    # no overlap -> NaN
    dist = np.clip(dist, 0.0, 1.0)                # clamp to [0,1]

    similarity = 1.0 - dist   

    # compute boost factor (now properly accounts for anchor-centric logic)
    total_weight = w.sum()
    total_count = len(cols)

    if boost == 'weight':
        if normalize:
            factor = np.where(total_weight > 0, used_w / total_weight, 0.0)
        else:
            factor = used_w.copy()
    else:  # 'count'
        if normalize:
            factor = used_cnt / total_count    # This now implements the 15/15, 14/15 logic
        else:
            factor = used_cnt.astype(float)

    score = similarity * factor

    out = pd.DataFrame({
        'distance': dist,
        'similarity': similarity,
        'score': score,
        'used_count': used_cnt,
        'used_weight': used_w
    }, index=X.index)

    out = out.sort_values(['score', 'similarity'], ascending=[False, False])
    return out

# %%
# default normalize True -> final score in [0,1]
q_idx = df.index[df['Material_Code'] == 'YYW-PN-G300297-E15'][0]

scores = gower_similarity(matches_expanded, query_idx=q_idx, boost='count', normalize=True, exclude_cols=['Material_Code', 'Legislation'])

# if you want the raw distance only:
scores.head()
# Out:
# /var/folders/hn/vdrc8_bx3bqbs08ppwsr68x00000gp/T/ipykernel_77853/4059106859.py:76: RuntimeWarning: All-NaN slice encountered
#   col_max = np.nanmax(A, axis=0)
# /var/folders/hn/vdrc8_bx3bqbs08ppwsr68x00000gp/T/ipykernel_77853/4059106859.py:77: RuntimeWarning: All-NaN slice encountered
#   col_min = np.nanmin(A, axis=0)
#        distance  similarity     score  used_count  used_weight
# 15065  0.098592    0.901408  0.901408          71         71.0
# 15067  0.102941    0.897059  0.859155          68         68.0
# 15066  0.104478    0.895522  0.845070          67         67.0
# 15068  0.722222    0.277778  0.140845          36         36.0

# %%
scores_index = scores.head(10).index

# %%
df.loc[scores_index]
# Out:
#             Material_Code Legislation  Min_Dry_Cocoa_Solids  Dry_Milk_Solids  \
# 15065  YYW-PN-G300297-E15          CA                   NaN              NaN
# 15067  YYW-PN-G300297-E15          US                   NaN              NaN
# 15066  YYW-PN-G300297-E15          MX                   NaN              NaN
# 15068  YYW-PN-G300297-E15         NaN                   NaN              NaN
#
#        MilkFat  Dry_Fat_Free_Cocoa_Solids Material_Group  \
# 15065      NaN                        NaN      Compounds
# 15067      NaN                        NaN      Compounds
# 15066      NaN                        NaN      Compounds
# 15068      NaN                        NaN      Compounds
#
#                                components_Specifications  Sugars_g  Protein_g  \
# 15065  {'natural flavouring': '0.02%', 'malt extract(...      53.8        4.0
# 15067  {'raising agent(e 500ii)': '0.38%', 'natural f...      53.8        4.0
# 15066  {'natural flavouring': '0.02%', 'malt extract(...      53.8        4.0
# 15068  {'toasted wheat crisp kosher': '20.0%', 'bc wh...       NaN        NaN
#
#        ...  Is_Organic  pH Normalised_Yield_Pa  \
# 15065  ...          No NaN                 NaN
# 15067  ...          No NaN                 NaN
# 15066  ...          No NaN                 NaN
# 15068  ...          No NaN                 NaN
#
#       Normalised_Linear_Viscosity_mPaS Normalised_Casson_Mpa_S  \
# 15065                              NaN                     NaN
# 15067                              NaN                     NaN
# 15066                              NaN                     NaN
# 15068                              NaN                     NaN
#
#       Brookfield_40C_S27_20_RPM Fineness_Micrometer Dimensions_Length  \
# 15065                       NaN                 NaN               NaN
# 15067                       NaN                 NaN               NaN
# 15066                       NaN                 NaN               NaN
# 15068                       NaN                 NaN               NaN
#
#       Dimensions_Width Dimensions_Count_lb
# 15065              NaN                 NaN
# 15067              NaN                 NaN
# 15066              NaN                 NaN
# 15068              NaN                 NaN
#
# [4 rows x 61 columns]
